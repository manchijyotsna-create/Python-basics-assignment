# %%
#Task 1
Name = "Jyotsna"
Age = 25
Height = 5.2
is_student = True
print(Name, Age, Height, is_student)
# Out:
# Jyotsna 25 5.2 True

# %%
#task 2
print(f"name:{Name} |age:{Age} |height:{Height} |is_student:{is_student}")
# Out:
# name:Jyotsna |age:25 |height:5.2 |is_student:True

# %%
#Task 3
Age_months = Age * 12
Age_days = Age * 365
Remainder = Age % 7
Age_square = Age ** 2
print ("Age in months:", Age_months)
print ("Age in days:", Age_days)
print ("Remainder when age divided by 7:", Remainder)
print ("Age squared:", Age_square)
# Out:
# Age in months: 300
# Age in days: 9125
# Remainder when age divided by 7: 4
# Age squared: 625
